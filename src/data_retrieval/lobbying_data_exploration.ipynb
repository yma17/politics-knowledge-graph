# %% [markdown]
# # Lobbying Data Formatting
# - Get names/IDs of lobbyists ("registrant") and who they contributed to ("contribution_items")
#     - Both in contribution data
# - Save the PACS info as well if applicable

# %% [markdown]
# ## Initial File Exploration

# %%
import json
import pandas as pd

# %%
lobbyist_json = "2021_lobbyists.json"

# %%
with open(lobbyist_json) as f:
    info = json.load(f)

# %%
lobbyist_data = info['results']

# %%
print(lobbyist_data[0])
# Out:
# {'url': 'https://lda.senate.gov/api/v1/filings/2da8c97a-0c80-4137-a257-e760cacb7c67/', 'filing_uuid': '2da8c97a-0c80-4137-a257-e760cacb7c67', 'filing_type': 'RR', 'filing_type_display': 'Registration', 'filing_year': 2021, 'filing_period': 'first_quarter', 'filing_period_display': '1st Quarter (Jan 1 - Mar 31)', 'filing_document_url': 'https://lda.senate.gov/filings/public/filing/2da8c97a-0c80-4137-a257-e760cacb7c67/print/', 'filing_document_content_type': 'text/html', 'income': None, 'expenses': None, 'expenses_method': None, 'expenses_method_display': None, 'posted_by_name': 'Amanda L. Wood', 'dt_posted': '2021-01-04T12:51:26-05:00', 'termination_date': None, 'registrant': {'id': 283696, 'url': 'https://lda.senate.gov/api/v1/registrants/283696/', 'house_registrant_id': 36844, 'name': 'BECKER & POLIAKOFF, P.A.', 'description': 'Law firm', 'address_1': '1275 K Street, NW', 'address_2': 'Suite 850', 'address_3': None, 'address_4': None, 'city': 'Washington', 'state': 'DC', 'state_display': 'District of Columbia', 'zip': '20005', 'country': 'US', 'country_display': 'United States of America', 'ppb_country': 'US', 'ppb_country_display': 'United States of America', 'contact_name': 'OMAR FRANCO', 'contact_telephone': '+1 202-621-7122', 'dt_updated': '2022-09-22T15:37:12.469901-04:00'}, 'client': {'id': 207872, 'url': 'https://lda.senate.gov/api/v1/clients/207872/', 'client_id': 1270, 'name': 'COUNTY OF HENNEPIN, MN', 'general_description': 'County government', 'client_government_entity': True, 'client_self_select': None, 'state': 'MN', 'state_display': 'Minnesota', 'country': 'US', 'country_display': 'United States of America', 'ppb_state': 'MN', 'ppb_state_display': 'Minnesota', 'ppb_country': 'US', 'ppb_country_display': 'United States of America', 'effective_date': '2021-01-01'}, 'lobbying_activities': [{'general_issue_code': 'ENV', 'general_issue_code_display': 'Environment/Superfund', 'description': 'Transportation infrastructure, health & human services, safety-net health services, climate change, criminal justice, housing & community development, taxes, and immigration', 'foreign_entity_issues': None, 'lobbyists': [{'lobbyist': {'id': 59711, 'prefix': None, 'prefix_display': None, 'first_name': 'CLARENCE', 'nickname': None, 'middle_name': None, 'last_name': 'WILLIAMS', 'suffix': None, 'suffix_display': None}, 'covered_position': 'Leg. Director/Chief of Staff, Rep. Kendrick B. Meek', 'new': True}, {'lobbyist': {'id': 59585, 'prefix': None, 'prefix_display': None, 'first_name': 'AMANDA', 'nickname': None, 'middle_name': 'L.', 'last_name': 'WOOD', 'suffix': None, 'suffix_display': None}, 'covered_position': 'Legislative Director, Sen. Bob Graham', 'new': True}, {'lobbyist': {'id': 53996, 'prefix': None, 'prefix_display': None, 'first_name': 'OMAR', 'nickname': None, 'middle_name': None, 'last_name': 'FRANCO', 'suffix': None, 'suffix_display': None}, 'covered_position': 'Chief of Staff, Rep. Mario Diaz-Balart', 'new': True}], 'government_entities': []}, {'general_issue_code': 'TAX', 'general_issue_code_display': 'Taxation/Internal Revenue Code', 'description': 'Transportation infrastructure, health & human services, safety-net health services, climate change, criminal justice, housing & community development, taxes, and immigration', 'foreign_entity_issues': None, 'lobbyists': [{'lobbyist': {'id': 59711, 'prefix': None, 'prefix_display': None, 'first_name': 'CLARENCE', 'nickname': None, 'middle_name': None, 'last_name': 'WILLIAMS', 'suffix': None, 'suffix_display': None}, 'covered_position': 'Leg. Director/Chief of Staff, Rep. Kendrick B. Meek', 'new': True}, {'lobbyist': {'id': 59585, 'prefix': None, 'prefix_display': None, 'first_name': 'AMANDA', 'nickname': None, 'middle_name': 'L.', 'last_name': 'WOOD', 'suffix': None, 'suffix_display': None}, 'covered_position': 'Legislative Director, Sen. Bob Graham', 'new': True}, {'lobbyist': {'id': 53996, 'prefix': None, 'prefix_display': None, 'first_name': 'OMAR', 'nickname': None, 'm ...

# %%
lobbyist_df = pd.DataFrame(lobbyist_data)

# %%
lobbyist_df.head()
# Out:
#                                                  url  \
# 0  https://lda.senate.gov/api/v1/filings/2da8c97a...
# 1  https://lda.senate.gov/api/v1/filings/afd3c75b...
# 2  https://lda.senate.gov/api/v1/filings/187c32ea...
# 3  https://lda.senate.gov/api/v1/filings/58097464...
# 4  https://lda.senate.gov/api/v1/filings/e60921f4...
#
#                             filing_uuid filing_type  \
# 0  2da8c97a-0c80-4137-a257-e760cacb7c67          RR
# 1  afd3c75b-de52-47ba-b262-1700d3667796          1T
# 2  187c32ea-632b-42a5-8536-6cacc7c68ff4          RR
# 3  58097464-e7ec-4001-b12b-489948eabc82          RR
# 4  e60921f4-3501-4b58-b33d-36b223457417          RR
#
#          filing_type_display  filing_year  filing_period  \
# 0               Registration         2021  first_quarter
# 1  1st Quarter - Termination         2021  first_quarter
# 2               Registration         2021  first_quarter
# 3               Registration         2021  first_quarter
# 4               Registration         2021  first_quarter
#
#           filing_period_display  \
# 0  1st Quarter (Jan 1 - Mar 31)
# 1  1st Quarter (Jan 1 - Mar 31)
# 2  1st Quarter (Jan 1 - Mar 31)
# 3  1st Quarter (Jan 1 - Mar 31)
# 4  1st Quarter (Jan 1 - Mar 31)
#
#                                  filing_document_url  \
# 0  https://lda.senate.gov/filings/public/filing/2...
# 1  https://lda.senate.gov/filings/public/filing/a...
# 2  https://lda.senate.gov/filings/public/filing/1...
# 3  https://lda.senate.gov/filings/public/filing/5...
# 4  https://lda.senate.gov/filings/public/filing/e...
#
#   filing_document_content_type    income  ... expenses_method_display  \
# 0                    text/html      None  ...                    None
# 1                    text/html  15000.00  ...                    None
# 2                    text/html      None  ...                    None
# 3                    text/html      None  ...                    None
# 4                    text/html      None  ...                    None
#
#      posted_by_name                         dt_posted termination_date  \
# 0    Amanda L. Wood         2021-01-04T12:51:26-05:00             None
# 1         Jeff Hogg  2021-01-05T11:16:52.930000-05:00       2021-01-01
# 2  Donald R. Bramer         2021-01-04T18:58:15-05:00             None
# 3     Ronald K Hamm         2021-01-04T15:24:01-05:00             None
# 4       Ronald Hamm         2021-01-04T22:18:52-05:00             None
#
#                                           registrant  \
# 0  {'id': 283696, 'url': 'https://lda.senate.gov/...
# 1  {'id': 401105690, 'url': 'https://lda.senate.g...
# 2  {'id': 401103355, 'url': 'https://lda.senate.g...
# 3  {'id': 400850504, 'url': 'https://lda.senate.g...
# 4  {'id': 400850504, 'url': 'https://lda.senate.g...
#
#                                               client  \
# 0  {'id': 207872, 'url': 'https://lda.senate.gov/...
# 1  {'id': 205894, 'url': 'https://lda.senate.gov/...
# 2  {'id': 207882, 'url': 'https://lda.senate.gov/...
# 3  {'id': 207880, 'url': 'https://lda.senate.gov/...
# 4  {'id': 207881, 'url': 'https://lda.senate.gov/...
#
#                                  lobbying_activities conviction_disclosures  \
# 0  [{'general_issue_code': 'ENV', 'general_issue_...                     []
# 1  [{'general_issue_code': 'TRD', 'general_issue_...                     []
# 2  [{'general_issue_code': 'MAN', 'general_issue_...                     []
# 3  [{'general_issue_code': 'TAX', 'general_issue_...                     []
# 4  [{'general_issue_code': 'URB', 'general_issue_...                     []
#
#   foreign_entities affiliated_organizations
# 0               []                       []
# 1               []                       []
# 2               []                       []
# 3               []                       []
# 4               []                       []
#
# [5 rows x 22 columns]

# %%
#lobbyist_df["lobbying_activities"][1]

# %%
l_names = []
l_ids = []
issue_codes = []
issue_descs = []

for row in lobbyist_df["lobbying_activities"]:
    for act in range(len(row)):
        #print(row[act])
        issue_code = row[act]["general_issue_code"]
        issue_desc = row[act]["general_issue_code_display"]
        num_lobbyists = len(row[act]["lobbyists"])
        issue_codes += [issue_code] * num_lobbyists
        issue_descs += [issue_desc] * num_lobbyists
        for lobbyist in row[act]["lobbyists"]:
            l = lobbyist["lobbyist"]
            l_id = l["id"]
            l_name = l["first_name"] + " " + l["last_name"]
            l_names.append(l_name)
            l_ids.append(l_id)

#print(l_names)
#print(l_ids)
#print(issue_codes)
#print(issue_descs)

# %%
lobby_df = pd.DataFrame({"name": l_names, "id": l_ids, "issue_code": issue_codes, "issue_desc":issue_descs})

# %%
lobby_df.head()
# Out:
#                 name     id issue_code                      issue_desc
# 0  CLARENCE WILLIAMS  59711        ENV           Environment/Superfund
# 1        AMANDA WOOD  59585        ENV           Environment/Superfund
# 2        OMAR FRANCO  53996        ENV           Environment/Superfund
# 3  CLARENCE WILLIAMS  59711        TAX  Taxation/Internal Revenue Code
# 4        AMANDA WOOD  59585        TAX  Taxation/Internal Revenue Code

# %%
lobby_df.to_csv("lobbyists_2019.csv")

# %%
lobbyist_df.columns
# Out:
# Index(['url', 'filing_uuid', 'filing_type', 'filing_type_display',
#        'filing_year', 'filing_period', 'filing_period_display',
#        'filing_document_url', 'filing_document_content_type', 'income',
#        'expenses', 'expenses_method', 'expenses_method_display',
#        'posted_by_name', 'dt_posted', 'termination_date', 'registrant',
#        'client', 'lobbying_activities', 'conviction_disclosures',
#        'foreign_entities', 'affiliated_organizations'],
#       dtype='object')

# %%
lobbyist_df["lobbying_activities"].iloc[1]
# Out:
# [{'general_issue_code': 'TRD',
#   'general_issue_code_display': 'Trade (domestic/foreign)',
#   'description': 'International wildlife trade.',
#   'foreign_entity_issues': '',
#   'lobbyists': [{'lobbyist': {'id': 73661,
#      'prefix': None,
#      'prefix_display': None,
#      'first_name': 'JEFF',
#      'nickname': None,
#      'middle_name': None,
#      'last_name': 'HOGG',
#      'suffix': None,
#      'suffix_display': None},
#     'covered_position': None,
#     'new': False}],
#   'government_entities': [{'id': 2, 'name': 'HOUSE OF REPRESENTATIVES'},
#    {'id': 1, 'name': 'SENATE'}]},
#  {'general_issue_code': 'ANI',
#   'general_issue_code_display': 'Animals',
#   'description': 'International animal trade.',
#   'foreign_entity_issues': '',
#   'lobbyists': [{'lobbyist': {'id': 73661,
#      'prefix': None,
#      'prefix_display': None,
#      'first_name': 'JEFF',
#      'nickname': None,
#      'middle_name': None,
#      'last_name': 'HOGG',
#      'suffix': None,
#      'suffix_display': None},
#     'covered_position': None,
#     'new': False}],
#   'government_entities': [{'id': 2, 'name': 'HOUSE OF REPRESENTATIVES'},
#    {'id': 1, 'name': 'SENATE'}]}]

# %%
lobbyist_df.shape
# Out:
# (25, 22)

# %%
contributions_json = "2019_contributions.json"

with open(contributions_json) as j:
    contrib_data = json.load(j)

# %%
contrib_df = pd.DataFrame(contrib_data)

# %%
contrib_df.head(10)
# Out:
#                                                  url  \
# 0  https://lda.senate.gov/api/v1/contributions/42...
# 1  https://lda.senate.gov/api/v1/contributions/3a...
# 2  https://lda.senate.gov/api/v1/contributions/29...
# 3  https://lda.senate.gov/api/v1/contributions/8a...
# 4  https://lda.senate.gov/api/v1/contributions/c1...
# 5  https://lda.senate.gov/api/v1/contributions/ec...
# 6  https://lda.senate.gov/api/v1/contributions/31...
# 7  https://lda.senate.gov/api/v1/contributions/f0...
# 8  https://lda.senate.gov/api/v1/contributions/04...
# 9  https://lda.senate.gov/api/v1/contributions/f7...
#
#                             filing_uuid filing_type filing_type_display  \
# 0  42f421fe-4d3f-4c0f-8658-ab278f555279          MM     Mid-Year Report
# 1  3a2a92b1-68b1-40ab-88ff-ad233fec6bdf          MM     Mid-Year Report
# 2  2994032e-ef18-40c7-bbc6-15124d12e6a4          MM     Mid-Year Report
# 3  8a1002b1-a7fa-4597-96ef-adae9bd9ec78          MM     Mid-Year Report
# 4  c1837954-6d4c-4711-a20d-f2b56d533770          MM     Mid-Year Report
# 5  ec5079b4-853d-4eae-9d5f-5e65548de67b          MM     Mid-Year Report
# 6  31c8c692-0d53-4e14-bfc3-0f606fa86e3d          MM     Mid-Year Report
# 7  f0f2fcde-a99a-43c9-b75a-97bfb8fd820c          MM     Mid-Year Report
# 8  04433f09-b34f-4e42-990b-3981d5dc1921          MM     Mid-Year Report
# 9  f784c0fd-6500-45bc-af46-125ffeba86a2          MM     Mid-Year Report
#
#    filing_year filing_period      filing_period_display  \
# 0         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 1         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 2         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 3         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 4         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 5         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 6         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 7         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 8         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 9         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
#
#                                  filing_document_url  \
# 0  https://lda.senate.gov/filings/public/contribu...
# 1  https://lda.senate.gov/filings/public/contribu...
# 2  https://lda.senate.gov/filings/public/contribu...
# 3  https://lda.senate.gov/filings/public/contribu...
# 4  https://lda.senate.gov/filings/public/contribu...
# 5  https://lda.senate.gov/filings/public/contribu...
# 6  https://lda.senate.gov/filings/public/contribu...
# 7  https://lda.senate.gov/filings/public/contribu...
# 8  https://lda.senate.gov/filings/public/contribu...
# 9  https://lda.senate.gov/filings/public/contribu...
#
#   filing_document_content_type    filer_type  ... state         state_display  \
# 0                    text/html      lobbyist  ...    VA              Virginia
# 1                    text/html      lobbyist  ...    DC  District of Columbia
# 2                    text/html      lobbyist  ...    MD              Maryland
# 3                    text/html      lobbyist  ...    DC  District of Columbia
# 4                    text/html      lobbyist  ...    DC  District of Columbia
# 5                    text/html      lobbyist  ...    DC  District of Columbia
# 6                    text/html      lobbyist  ...    DC  District of Columbia
# 7                    text/html  organization  ...    DC  District of Columbia
# 8                    text/html      lobbyist  ...    VA              Virginia
# 9                    text/html      lobbyist  ...    DC  District of Columbia
#
#      zip country           country_display  \
# 0  22314      US  United States of America
# 1  20001      US  United States of America
# 2  20850      US  United States of America
# 3  20005      US  United States of America
# 4  20004      US  United States of America
# 5  20005      US  United States of America
# 6  20002      US  United States of America
# 7  20003      US  United States of America
# 8  22203      US  United States of America
# 9  20001      US  United States of America
#
#                                           registrant  \
# 0  {'id': 65191, 'url': 'https://lda.senate.gov/a...
# 1  {'id': 21027, 'url': 'https://lda.senate.gov/a...
# 2  {'id': 25055, 'url': 'https://lda.senate.gov/a...
# 3  {'id': 320793, 'url': 'https://lda.senate.gov/...
# 4  {'id': 37948, 'url': 'https://lda.senate.gov/a...
# 5  {'id': 7257, 'url': 'https://lda.senate.gov/ap...
# 6  {'id': 5506, 'url': 'https://lda.senate.gov/ap...
# 7  {'id': 48805, 'url': 'https://lda.senate.gov/a...
# 8  {'id': 301573, 'url': 'https://lda.senate.gov/...
# 9  {'id': 2877, 'url': 'https://lda.senate.gov/ap...
#
#                                             lobbyist no_contributions pacs  \
# 0  {'id': 69168, 'prefix': None, 'prefix_display'...             True   []
# 1  {'id': 7484, 'prefix': 'mr', 'prefix_display':...             True   []
# 2  {'id': 57861, 'prefix': 'mr', 'prefix_display'...             True   []
# 3  {'id': 63507, 'prefix': None, 'prefix_display'...             True   []
# 4  {'id': 41484, 'prefix': None, 'prefix_display'...             True   []
# 5  {'id': 62502, 'prefix': None, 'prefix_display'...             True   []
# 6  {'id': 68338, 'prefix': None, 'prefix_display'...             True   []
# 7                                               None            False   []
# 8  {'id': 65598, 'prefix': None, 'prefix_display'...             True   []
# 9  {'id': 2879, 'prefix': 'mr', 'prefix_display':...             True   []
#
#                                   contribution_items
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7  [{'contribution_type': 'feca', 'contribution_t...
# 8                                                 []
# 9                                                 []
#
# [10 rows x 27 columns]

# %%
made_contrib = contrib_df[contrib_df["no_contributions"] == False].copy()

# %%
made_contrib = made_contrib.reset_index()
made_contrib.head()
# Out:
#    index                                                url  \
# 0      7  https://lda.senate.gov/api/v1/contributions/f0...
# 1     27  https://lda.senate.gov/api/v1/contributions/1d...
# 2     29  https://lda.senate.gov/api/v1/contributions/7b...
# 3     30  https://lda.senate.gov/api/v1/contributions/c8...
# 4     32  https://lda.senate.gov/api/v1/contributions/fd...
#
#                             filing_uuid filing_type filing_type_display  \
# 0  f0f2fcde-a99a-43c9-b75a-97bfb8fd820c          MM     Mid-Year Report
# 1  1dded0ed-8b35-4c1f-ad31-7c2d241ccba8          MM     Mid-Year Report
# 2  7b01d95b-3b44-481c-8caa-9da46f65d110          MA  Mid-Year Amendment
# 3  c8d7f1c6-c357-4116-baa9-6388013a9a6a          MM     Mid-Year Report
# 4  fdea3d75-044c-4dea-8f4f-061d58d4d289          MM     Mid-Year Report
#
#    filing_year filing_period      filing_period_display  \
# 0         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 1         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 2         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 3         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
# 4         2019      mid_year  Mid-Year (Jan 1 - Jun 30)
#
#                                  filing_document_url  \
# 0  https://lda.senate.gov/filings/public/contribu...
# 1  https://lda.senate.gov/filings/public/contribu...
# 2  https://lda.senate.gov/filings/public/contribu...
# 3  https://lda.senate.gov/filings/public/contribu...
# 4  https://lda.senate.gov/filings/public/contribu...
#
#   filing_document_content_type  ... state         state_display    zip  \
# 0                    text/html  ...    DC  District of Columbia  20003
# 1                    text/html  ...    DC  District of Columbia  20036
# 2                    text/html  ...    DC  District of Columbia  20003
# 3                    text/html  ...    DC  District of Columbia  20003
# 4                    text/html  ...    VA              Virginia  22205
#
#   country           country_display  \
# 0      US  United States of America
# 1      US  United States of America
# 2      US  United States of America
# 3      US  United States of America
# 4      US  United States of America
#
#                                           registrant  \
# 0  {'id': 48805, 'url': 'https://lda.senate.gov/a...
# 1  {'id': 6256, 'url': 'https://lda.senate.gov/ap...
# 2  {'id': 38687, 'url': 'https://lda.senate.gov/a...
# 3  {'id': 38687, 'url': 'https://lda.senate.gov/a...
# 4  {'id': 400745228, 'url': 'https://lda.senate.g...
#
#                                             lobbyist no_contributions pacs  \
# 0                                               None            False   []
# 1  {'id': 62131, 'prefix': None, 'prefix_display'...            False   []
# 2  {'id': 7922, 'prefix': 'ms', 'prefix_display':...            False   []
# 3  {'id': 7922, 'prefix': 'ms', 'prefix_display':...            False   []
# 4  {'id': 69446, 'prefix': None, 'prefix_display'...            False   []
#
#                                   contribution_items
# 0  [{'contribution_type': 'feca', 'contribution_t...
# 1  [{'contribution_type': 'feca', 'contribution_t...
# 2  [{'contribution_type': 'feca', 'contribution_t...
# 3  [{'contribution_type': 'feca', 'contribution_t...
# 4  [{'contribution_type': 'feca', 'contribution_t...
#
# [5 rows x 28 columns]

# %%
lobbyist_id = []
lobbyist_name = []
for row in made_contrib["lobbyist"]:
    if row != None:
        lobbyist_id.append(row["id"])
        lobbyist_name.append(row["first_name"] + " " + row["last_name"])
    else:
        lobbyist_id.append("")
        lobbyist_name.append("")

made_contrib["lobbyist_name"] = lobbyist_name
made_contrib["lobbyist_id"] = lobbyist_id

# %%
registrant_names = []
house_registrant_id = []
senate_registrant_id = []
pacs = []
con_items = []
lobbyist_id = []
lobbyist_name = []

# %%
for row in made_contrib.itertuples():
    #print(row)
    #break
    registrant = row[24]
    pac = row[27]
    contribution_items = row[28]
    con_items += contribution_items
    registrant_names += [registrant["name"]] * len(contribution_items)
    house_registrant_id += [registrant["house_registrant_id"]] * len(contribution_items)
    senate_registrant_id += [registrant["id"]] * len(contribution_items)
    lobbyist_id += [row[30]] * len(contribution_items)
    lobbyist_name += [row[29]] * len(contribution_items)
    if pac != []:
        pacs += [pac] * len(contribution_items)
    else:
        pacs += ["None"] * len(contribution_items)

# %%
con_df = pd.DataFrame(con_items)

# %%
con_df.head()
# Out:
#   contribution_type contribution_type_display  \
# 0              feca                      FECA
# 1              feca                      FECA
# 2              feca                      FECA
# 3              feca                      FECA
# 4              feca                      FECA
#
#                           contributor_name                     payee_name  \
# 0  WAYNE STATE UNIVERSITY DETROIT MICHIGAN         JAMES M. WILLIAMS, JR.
# 1                   LISTER, JAMES HARDWICK         ALASKANS FOR DON YOUNG
# 2                       LOWE, JOCELYN HONG         XOCHITL FOR NEW MEXICO
# 3                       LOWE, JOCELYN HONG  STEPHANIE MURPHY FOR CONGRESS
# 4                       LOWE, JOCELYN HONG                   AT THE TABLE
#
#            honoree_name  amount        date
# 0         Kamala Harris  110.00  2019-01-22
# 1             Don Young  500.00  2019-03-05
# 2  Xochitl Torres Small  100.00  2019-03-13
# 3      Stephanie Murphy  100.00  2019-03-13
# 4                   PAC  100.00  2019-03-13

# %%
con_df["pac"] = pacs
con_df["registrant_house_id"] = house_registrant_id
con_df["senate_registrant_id"] = senate_registrant_id
con_df["registrant"] = registrant_names
con_df["lobbyist_id"] = lobbyist_id
con_df["lobbyist_name"] = lobbyist_name

# %%
con_df.to_csv("contributions_2019.csv")

# %% [markdown]
# ## Contributor JSON File Downloads

# %%
import requests
import json

# %%
contributions_url = "https://lda.senate.gov/api/v1/contributions/"
filing_years = [2019, 2020, 2021]
api_key = "1620156b847c54ddc0bd6c5ead8e2113cdb8cd4d"

# %%
# Make initial request for given year
# Write obtained info to the corresponding file
# Get the value for the next page
# If no value exists (next = null), then break
# Otherwise, make new request and repeat

# %%
#params = {"filing_year": 2021, "page": 1}
#all_results = []
#while True:
#    r = requests.get(contributions_url, params, headers={"api_key":api_key})
#    data = r.json()
#    #print(data)
#    if "results" in list(data.keys()):
#        all_results += data["results"]
#    if "next" not in list(data.keys()):
#        break
#    params["page"] += 1
#    if params["page"] % 10 == 0:
#        print(params["page"])

# %%
#with open("2021_cotributions.json", mode="w+") as f:
#    f.write("[")
#    for ind, item in enumerate(all_results):
#        f.write(json.dumps(item))
#        if ind != len(all_results) - 1:
#            f.write(",")
#        f.write("\n")
#    f.write("]")
